# %%
import copy

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.collections import LineCollection
from matplotlib.patches import Rectangle
from model import get_fuente2024
from mxlpy import Model, Simulator, cartesian_product, make_protocol, scan
from mxlpy.parallel import parallelise

import mxlbricks.names as n

# %% [markdown]
# # Str Dict

# %%
pfd_str = n.pfd()
pfd_add_str = n.pfd("_add")
light_str = "osc_light"
pqox_str = n.pq_ox()
hlumen_str = n.h("_lumen")
qactive_str = n.quencher("_active")
atp_stroma_str = n.atp("_stroma")
atot_str = n.total_adenosines()
ps1ox_str = n.ps1("_ox")
ps1total_str = n.ps1("_total")
o2_str = n.o2()
npq_str = "NPQ"
flou_str = n.fluorescence()
pqtotal_str = n.total_pq()

# %% [markdown]
# # Figure 2

# %%
def fig2_sim(
    m: Model,
    pfd_str: str,
    pfr_add_str: str
):
    pfd = np.mean([50, 950])
    
    m.update_parameters({
        "f": 1 / 10000,
        pfd_str: pfd,
        pfr_add_str: 950 - pfd
    })

    s = Simulator(m)

    s.simulate(40000)

    res = s.get_result().unwrap_or_err().get_combined()

    return res, m

def fig2_plot(
    res: pd.DataFrame,
    m: Model,
    light_str: str,
    pqox_str: str,
    hlumen_str: str,
    qactive_str: str,
    atp_stroma_str: str,
    atot_str: str,
    ps1ox_str: str
):
    
    fig, axs = plt.subplots(3, 2, figsize=(10, 8))

    light_diff = res[light_str].diff()
    light_color = "#fdb338ff"
    dark_color = "#025196ff"

    new_res = pd.DataFrame()
    new_res["light"] = res[light_str]
    new_res["pq_ox"] = res[pqox_str]
    new_res["-log_Hlumen"] = -np.log10(res[hlumen_str] * 10**(-6))
    new_res["quencher_active"] = res[qactive_str]
    new_res["atp_stroma_ratio"] = res[atp_stroma_str] / m.get_parameter_values()[atot_str]
    new_res["ps1_ox"] = res[ps1ox_str]


    for ax, res_str in zip(axs.flatten(), new_res.columns, strict=False):
        points = np.array([new_res.index, new_res[res_str].values]).T.reshape(-1, 1, 2)
        segments = np.concatenate([points[:-1], points[1:]], axis=1)
        colors = np.where(light_diff >= 0, light_color, dark_color)
        lc = LineCollection(segments, colors=colors, linewidths=2)

        ax.add_collection(lc)
        
        ax.set_xlim(new_res.index.min(), new_res.index.max())
        ax.set_ylim(new_res[res_str].min(), new_res[res_str].max())

    for ax in axs.flatten():
        ax.set_xlim(2e4, 4e4)
        ax.set_xticks(np.linspace(2e4, 4e4, 5))
        ax.set_xlabel("Time (s)")
        
    axs[0,0].set_ylabel("Light Intensity (µmol photons m$^{-2}$ s$^{-1}$)")
    axs[0,0].set_ylim(0, 1100)
    axs[0,0].set_yticks(np.linspace(0, 1000, 6))

    axs[0,1].set_ylabel(r"Oxidized PQ (PQ $\cdot$ PSII$^{-1}$)")
    axs[0,1].set_ylim(1, 5)
    axs[0,1].set_yticks(np.linspace(1, 5, 5))

    axs[1,0].set_ylabel(r"Lumen pH")
    axs[1,0].set_ylim(5.6, 6.6)
    axs[1,0].set_yticks(np.linspace(5.6, 6.6, 6))

    axs[1,1].set_ylabel(r"Active quencher (rel. units)")
    axs[1,1].set_ylim(0, 1)
    axs[1,1].set_yticks(np.linspace(0, 1, 6))

    axs[2,0].set_ylabel(r"ATP/Stroma Ratio")
    axs[2,0].set_ylim(0, 1)
    axs[2,0].set_yticks(np.linspace(0, 1, 6))

    axs[2,1].set_ylabel(r"PI$_{ox}$ (rel. units)")
    axs[2,1].set_ylim(0, 0.8)
    axs[2,1].set_yticks(np.linspace(0, 0.8, 5))

    return fig, axs

# %%
fig2_res, fig2_m = fig2_sim(
    m=get_fuente2024(),
    pfd_str=pfd_str,
    pfr_add_str=pfd_add_str
)

fig2, axs2 = fig2_plot(
    res=fig2_res,
    m=fig2_m,
    light_str=light_str,
    pqox_str=pqox_str,
    hlumen_str=hlumen_str,
    qactive_str=qactive_str,
    atp_stroma_str=atp_stroma_str,
    atot_str=atot_str,  
    ps1ox_str=ps1ox_str
)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Figure 3

# %%
def fig3_sim(
    m: Model,
    pfd_str: str,
    pfd_add_str: str
):
    m.update_parameters({
        pfd_add_str: 0
    })
    
    res = scan.steady_state(
        model=m,
        to_scan=pd.DataFrame({
            pfd_str: np.linspace(10, 1000, 100)
        })
    )
    
    return res.combined, m

def fig3_plot(
    m: Model,
    res: pd.DataFrame,
    atp_stroma_str: str,
    atot_str: str,
    qactive_str: str,
    hlumen_str: str,
    ps1ox_str: str,
    ps1total_str: str,
    pqox_str: str,
    pqtotal_str: str,
    o2_str: str,
    npq_str: str,
    flou_str: str
):
    fig, axs = plt.subplots(ncols=2, figsize=(12, 5))
    
    new_res = pd.DataFrame()
    new_res["atp_stroma"] = res[atp_stroma_str] / m.get_parameter_values()[atot_str]
    new_res["active_quencher"] = res[qactive_str]
    new_res["lumen_pH"] = -np.log10(res[hlumen_str] * 10**(-6))
    new_res["ps1_ox"] = res[ps1ox_str] / m.get_parameter_values()[ps1total_str]
    new_res["pq_ox"] = res[pqox_str] / m.get_parameter_values()[pqtotal_str]
    new_res["o2"] = res[o2_str]
    new_res["npq"] = res[npq_str]
    new_res["flou"] = res[flou_str]
    
    
    style_dict = {
        "atp_stroma": {
            "color": "#8eb133",
            "label": "ATP"
        },
        "active_quencher": {
            "color": "#e19d20",
            "label": "Active Quencher"
        },
        "lumen_pH": {
            "color": "#000000",
            "label": "Lumen pH"
        },
        "ps1_ox": {
            "color": "#f16431",
            "label": "PI$_{ox}$"
        },
        "pq_ox": {
            "color": "#5f7fb6",
            "label": "Oxidized PQ"
        },
        "o2": {
            "color": "#000000",
            "label": "O$_2$ evolution"
        },
        "npq": {
            "color": "#e29c23",
            "label": "NPQ"
        },
        "flou": {
            "color": "#5b82b5",
            "label": "ChlF"
        }
    }
    
    ax_lumen = axs[0].twinx()
    ax_o2 = axs[1].twinx()
    
    for col_str in new_res.columns:
        if col_str == "lumen_pH":
            ax = ax_lumen
        elif col_str == "o2":
            ax = ax_o2
        elif col_str in ["npq", "flou"]:
            ax = axs[1]
        else:
            ax = axs[0]
        ax.plot(
            new_res.index,
            new_res[col_str],
            color=style_dict[col_str]["color"],
            linewidth=2
        )
        
    for ax in axs:
        ax.set_xlabel(r"Light Intensity (µmol photons $\cdot$ m$^{-2}$ $\cdot$ s$^{-1}$)")
        ax.set_xlim(-10, 1010)
        ax.set_xticks(np.linspace(0, 1000, 6))
        
        ax.add_patch(
            Rectangle(
                (0, ax.get_ylim()[0]),
                50,
                ax.get_ylim()[1] - ax.get_ylim()[0],
                color="black",
                alpha=0.1,
                zorder=-1
            )
        )
        
    axs[0].set_ylabel("Concentrations Ratios")
    axs[0].set_ylim(0, 0.9)
    axs[0].set_yticks(np.linspace(0.2, 0.8, 4))
    ax_lumen.set_ylabel("Lumen pH")
    ax_lumen.set_ylim(5.0, 6.8)
    ax_lumen.set_yticks(np.linspace(5.4, 6.6, 4))
    
    axs[1].set_ylabel("NPQ \n ChlF (rel. units)")
    axs[1].set_ylim(0, 1.25)
    axs[1].set_yticks(np.linspace(00, 1.2, 7))
    ax_o2.set_ylabel(r"O$_2$ rate \n (mol O$_2$ $\cdot$ mol PSIIRC$^{-1}$ $\cdot$ s$^{-1}$)")
    ax_o2.set_ylim(0, 121)
    ax_o2.set_yticks(np.linspace(0, 120, 7))
    
    
    return fig, axs

# %%
fig3_res, fig3_m = fig3_sim(
    m=get_fuente2024(),
    pfd_str=pfd_str,
    pfd_add_str=pfd_add_str
)

fig3, axs3 = fig3_plot(
    m=fig3_m,
    res=fig3_res,
    atp_stroma_str=atp_stroma_str,
    atot_str=atot_str,
    qactive_str=qactive_str,
    hlumen_str=hlumen_str,
    ps1ox_str=ps1ox_str,
    ps1total_str=ps1total_str,
    pqox_str=pqox_str,
    pqtotal_str=pqtotal_str,
    o2_str=o2_str,
    npq_str=npq_str,
    flou_str=flou_str
)

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 100/100 [00:29<00:00,  3.41it/s]

# %% [markdown]
# # Figure 4

# %%
def fig4_parralel_func(dic):
    s = Simulator(dic["model"])
    
    s.update_parameter("f", dic["f_val"])
    
    s.simulate(dic["sim_end"])
    
    return s.get_result().unwrap_or_err().get_combined()

def fig4_sim(
    m: Model,
    pfd_str: str,
    pfd_add_str: str
):
    
    full_res = None
    pfds = [(50, 950), (50, 150)]
    Ts = [10000, 1000, 100, 1, 0.1, 0.001]
    sim_ends = [50000, 5000, 500, 5, 0.5, 0.005]
    
    for pfd_vals in pfds:
        model_copy = copy.deepcopy(m)
        model_copy.update_parameters({
            pfd_str: np.mean(pfd_vals),
            pfd_add_str: pfd_vals[1] - np.mean(pfd_vals)
        })

        res = parallelise(
            fn=fig4_parralel_func,
            inputs=[(T, {"model": model_copy, "f_val": 1/T, "sim_end": s}) for i, (T, s) in enumerate(zip(Ts, sim_ends))],
        )
        
        res = pd.concat([i[1] for i in res], keys=[i[0] for i in res], names=["T", "time"])
        
        if full_res is None:
            full_res = pd.concat([res], keys=[f"{pfd_vals}"], names=["pfds"])
        else:
            full_res = pd.concat([full_res, pd.concat([res], keys=[f"{pfd_vals}"], names=["pfds"])])
        
    return full_res, model_copy

def fig4_plot(
    res: pd.DataFrame,
    m: Model,
    pqox_str: str,
    hlumen_str: str,
    qactive_str: str,
    atp_stroma_str: str,
    atot_str: str,
    ps1ox_str: str,
    light_str: str,
):
    
    fig, axs = plt.subplots(ncols=5, nrows=6, figsize=(20, 20))
    
    
    light_color = "#fdb338ff"
    dark_color = "#025196ff"
    
    dash_pattern = (0, (1, 2))
    
    xlims = [(2e4, 4e4), (2e3, 4e3), (2e2, 4e2), (2e0, 4e0), (2e-1, 4e-1), (2e-3, 4e-3)]
    ylims = [(1, 6), (5.5, 7.0), (0, 1), (0, 1.0), (0, 1)]
    titles = [
        r"Oxidized PQ (PQ $\cdot$ PSII$^{-1}$)",
        r"Lumen pH",
        r"Active quencher (rel. units)",
        r"ATP / Total Adenosines",
        r"PI$_{ox}$ (rel. units)"
    ]
    
    for pfds in res.index.get_level_values("pfds").unique():
        new_res_pfds = res.loc[pfds]
        
        current_ls = "solid" if pfds == "(50, 950)" else dash_pattern
        
        for row, T in enumerate(res.index.get_level_values('T').unique()):
            new_res = new_res_pfds.loc[T]
            true_res = pd.DataFrame()
            true_res["pq_ox"] = new_res[pqox_str]
            true_res["-log_Hlumen"] = -np.log10(new_res[hlumen_str] * 10**(-6))
            true_res["quencher_active"] = new_res[qactive_str]
            true_res["atp_stroma_ratio"] = new_res[atp_stroma_str] / m.get_parameter_values()[atot_str]
            true_res["ps1_ox"] = new_res[ps1ox_str]
            
            light_diff = new_res[light_str].diff().fillna(0)
            for col, res_str in enumerate(true_res.columns):
            
                points = np.array([true_res.index, true_res[res_str].values]).T.reshape(-1, 1, 2)
                segments = np.concatenate([points[:-1], points[1:]], axis=1)
                colors = np.where(light_diff >= 0, light_color, dark_color)
                lc = LineCollection(
                    segments, 
                    colors=colors, 
                    linewidths=2, 
                    linestyles=current_ls,
                    capstyle="butt",
                    zorder=1
                )

                axs[row,col].add_collection(lc)
                if current_ls != "solid":
                    axs[row,col].plot(true_res[res_str], color="white", lw=2.5, zorder=2, ls=dash_pattern)
                
                axs[row,col].set_ylim(ylims[col])
                
                if row == 0:
                        axs[0,col].set_title(titles[col])
                if row == len(res.index.get_level_values('T').unique()) - 1:
                    axs[row,col].set_xlabel("Time (s)")

            for ax in axs[row, :]:
                ax.set_xlim(xlims[row])
                ax.set_xticks(np.linspace(xlims[row][0], xlims[row][1], 5))
                
            axs[row,0].set_ylabel(f"T = {T} s")
                
    
    return fig, axs

# %%
fig4_res, fig4_model = fig4_sim(
    m=get_fuente2024(),
    pfd_str=pfd_str,
    pfd_add_str=pfd_add_str
)

fig4_plot(
    res=fig4_res,
    m=fig4_model,
    pqox_str=pqox_str,
    hlumen_str=hlumen_str,
    qactive_str=qactive_str,
    atp_stroma_str=atp_stroma_str,
    atot_str=atot_str,
    ps1ox_str=ps1ox_str,
    light_str=light_str
)

plt.tight_layout()
plt.show()
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]Process pebble_pool_worker:
# Traceback (most recent call last):
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 433, in worker_process
#     process_tasks(params, channel)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 441, in process_tasks
#     for task in worker_get_next_task(channel, params.max_tasks):
#                 ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 453, in worker_get_next_task
#     yield fetch_task(channel)
#           ~~~~~~~~~~^^^^^^^^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 467, in fetch_task
#     return task_transaction(channel)
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 476, in task_transaction
#     task = channel.recv()
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/channel.py", line 103, in recv
#     return self.reader.recv()
#            ~~~~~~~~~~~~~~~~^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/multiprocessing/connection.py", line 257, in recv
#     return _ForkingPickler.loads(buf.getbuffer())
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
# AttributeError: module '__main__' has no attribute 'fig4_parralel_func'
# Process pebble_pool_worker:
# Traceback (most recent call last):
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 433, in worker_process
#     process_tasks(params, channel)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 441, in process_tasks
#     for task in worker_get_next_task(channel, params.max_tasks):
#                 ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 453, in worker_get_next_task
#     yield fetch_task(channel)
#           ~~~~~~~~~~^^^^^^^^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 467, in fetch_task
#     return task_transaction(channel)
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 476, in task_transaction
#     task = channel.recv()
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/channel.py", line 103, in recv
#     return self.reader.recv()
#            ~~~~~~~~~~~~~~~~^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/multiprocessing/connection.py", line 257, in recv
#     return _ForkingPickler.loads(buf.getbuffer())
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
# AttributeError: module '__main__' has no attribute 'fig4_parralel_func'
# Process pebble_pool_worker:
# Traceback (most recent call last):
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 433, in worker_process
#     process_tasks(params, channel)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 441, in process_tasks
#     for task in worker_get_next_task(channel, params.max_tasks):
#                 ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 453, in worker_get_next_task
#     yield fetch_task(channel)
#           ~~~~~~~~~~^^^^^^^^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 467, in fetch_task
#     return task_transaction(channel)
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/process.py", line 476, in task_transaction
#     task = channel.recv()
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/pebble/pool/channel.py", line 103, in recv
#     return self.reader.recv()
#            ~~~~~~~~~~~~~~~~^^
#   File "/home/elouencorvestnew/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/multiprocessing/connection.py", line 257, in recv
#     return _ForkingPickler.loads(buf.getbuffer())
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
# AttributeError: module '__main__' has no attribute 'fig4_parralel_func'
#   0%|          | 0/6 [00:04<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 fig4_res, fig4_model = fig4_sim(
#       2     m=get_fuente2024(),
#       3     pfd_str=pfd_str,
#       4     pfd_add_str=pfd_add_str
#       5 )
#       7 fig4_plot(
#       8     res=fig4_res,
#       9     m=fig4_model,
#    (...)     16     light_str=light_str
#      17 )
#      19 plt.tight_layout()
#
# Cell In[8], line 28, in fig4_sim(m, pfd_str, pfd_add_str)
#      22 model_copy = copy.deepcopy(m)
#      23 model_copy.update_parameters({
#      24     pfd_str: np.mean(pfd_vals),
#      25     pfd_add_str: pfd_vals[1] - np.mean(pfd_vals)
#      26 })
# ---> 28 res = parallelise(
#      29     fn=fig4_parralel_func,
#      30     inputs=[(T, {"model": model_copy, "f_val": 1/T, "sim_end": s}) for i, (T, s) in enumerate(zip(Ts, sim_ends))],
#      31 )
#      33 res = pd.concat([i[1] for i in res], keys=[i[0] for i in res], names=["T", "time"])
#      35 if full_res is None:
#
# File ~/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/site-packages/mxlpy/parallel.py:152, in parallelise(fn, inputs, cache, parallel, max_workers, timeout, disable_tqdm, tqdm_desc)
#     143 with (
#     144     tqdm(
#     145         total=len(inputs),
#    (...)    149     pebble.ProcessPool(max_workers=max_workers) as pool,
#     150 ):
#     151     future = pool.map(worker, inputs, timeout=timeout)
# --> 152     it = future.result()
#     153     while True:
#     154         try:
#
# File ~/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/concurrent/futures/_base.py:445, in Future.result(self, timeout)
#     442 elif self._state == FINISHED:
#     443     return self.__get_result()
# --> 445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     448     raise CancelledError()
#
# File ~/Documents/mxl-bricks-elouen/.pixi/envs/default/lib/python3.14/threading.py:369, in Condition.wait(self, timeout)
#     367 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     368     if timeout is None:
# --> 369         waiter.acquire()
#     370         gotit = True
#     371     else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Figure 5

# %%
def fig5_plot(
    res: pd.DataFrame,
    m: Model,
    light_str: str,
    o2_str: str,
    npq_str: str,
    flou_str: str
):
    
    fig, axs = plt.subplots(ncols=3, nrows=6, figsize=(20, 20))
    
    
    light_color = "#fdb338ff"
    dark_color = "#025196ff"
    
    dash_pattern = (0, (1, 2))
    
    xlims = [(2e4, 4e4), (2e3, 4e3), (2e2, 4e2), (2e0, 4e0), (2e-1, 4e-1), (2e-3, 4e-3)]
    ylims = [(0, 0.5), (0, 1.5), (0, 120)]
    titles = [
        r"ChlF (rel. units)",
        r"NPQ",
        r"O$_2$ rate \n (mol O$_2$ $\cdot$ mol PSIIRC$^{-1}$ $\cdot$ s$^{-1}$)"
    ]
    
    for pfds in res.index.get_level_values("pfds").unique():
        new_res_pfds = res.loc[pfds]
        
        current_ls = "solid" if pfds == "(50, 950)" else dash_pattern
        
        for row, T in enumerate(res.index.get_level_values('T').unique()):
            new_res = new_res_pfds.loc[T]
            true_res = pd.DataFrame()
            true_res["flou"] = new_res[flou_str]
            true_res["npq"] = new_res[npq_str]
            true_res["o2"] = new_res[o2_str]
            
            light_diff = new_res[light_str].diff().fillna(0)
            for col, res_str in enumerate(true_res.columns):
            
                points = np.array([true_res.index, true_res[res_str].values]).T.reshape(-1, 1, 2)
                segments = np.concatenate([points[:-1], points[1:]], axis=1)
                colors = np.where(light_diff >= 0, light_color, dark_color)
                lc = LineCollection(
                    segments, 
                    colors=colors, 
                    linewidths=2, 
                    linestyles=current_ls,
                    capstyle="butt",
                    zorder=1
                )

                axs[row,col].add_collection(lc)
                if current_ls != "solid":
                    axs[row,col].plot(true_res[res_str], color="white", lw=2.5, zorder=2, ls=dash_pattern)
                
                axs[row,col].set_ylim(ylims[col])
                
                if row == 0:
                        axs[0,col].set_title(titles[col])
                if row == len(res.index.get_level_values('T').unique()) - 1:
                    axs[row,col].set_xlabel("Time (s)")

            for ax in axs[row, :]:
                ax.set_xlim(xlims[row])
                ax.set_xticks(np.linspace(xlims[row][0], xlims[row][1], 5))
                
            axs[row,0].set_ylabel(f"T = {T} s")
                
    
    return fig, axs

# %%
fig5_res, fig5_model = fig4_sim(
    m=get_fuente2024(),
    pfd_str=pfd_str,
    pfd_add_str=pfd_add_str
)

fig5_plot(
    res=fig5_res,
    m=fig5_model,
    light_str=light_str,
    o2_str=o2_str,
    npq_str=npq_str,
    flou_str=flou_str
)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Figure 6

# %%
# Sample signal
x = np.array([1.0, 2.0, 1.0, -1.0])

# Calculate the DFT (FFT)
X = np.fft.fft(x)

# Get the real part
real_part = X.real

# Get the imaginary part
imaginary_part = X.imag

print("DFT Result:", X)
print("Real Numbers:", real_part)
print("Imaginary Numbers:", imaginary_part)

# %%
def fig6_sim(
    m: Model,
    pfd_str: str,
    pfd_add_str: str
):
    
    # f = 1 / 500
    # sampling_interval = 1 / 100 * f
    
    # m.update_parameters({
    #     pfd_str: 500,
    #     pfd_add_str: 450,
    #     "f": f
    # })
    
    # s = Simulator(m)
    # s.simulate(3000, steps = 200)
    # res = s.get_result().unwrap_or_err().get_combined()
    
    # freqs = np.fft.fft(res[flou_str].values)
    
    # amplitudes = np.sqrt(freqs.real**2 + freqs.imag**2)
    # phases = np.arctan(freqs.imag / freqs.real)
    # print(phases)
    # amps = {}
    # phas = {}
    # for label, multiplier in [("Fundamental (1/T)", 1), 
    #                            ("2nd Harmonic (2/T)", 2), 
    #                            ("3rd Harmonic (3/T)", 3), 
    #                            ("4th Harmonic (4/T)", 4)]:
        
    #     target_f = multiplier * f
    #     idx = np.argmin(np.abs(freqs - target_f))
        
    #     amps[label] = amplitudes[idx]
    #     phas[label] = phases[idx]
    
    # results = pd.DataFrame()
    # results["Amplitudes"] = amps
    # results["Phases"] = phas
    
    # return res, results, m
    
    f = 1 / 500
    
    m.update_parameters({
        pfd_str: 500,
        pfd_add_str: 450,
        "f": f
    })
    
    s = Simulator(m)
    s.simulate(3000, steps = 200)
    res = s.get_result().unwrap_or_err().get_combined()
    
    fluorescence_signal = res[flou_str]
    T = 500  # Period of the oscillation
    
    # 1. Setup Timing Parameters based on the paper
    N = len(fluorescence_signal)           # Should be 201 [cite: 460]
    dt = T / 100                           # Sampling interval [cite: 459]
    time = np.arange(N) * dt
    
    # 2. Perform DFT [cite: 462]
    dft_complex = np.fft.fft(fluorescence_signal)
    freqs = np.fft.fftfreq(N, dt)
    
    # 3. Calculate Amplitude and Phase for the plot [cite: 821, 822]
    # Normalizing amplitude by 2/N to match physical units
    amplitudes = np.sqrt(dft_complex.real**2 + dft_complex.imag**2)
    phases = np.arctan(dft_complex.imag / dft_complex.real)
    
    # The paper notes f0 (average) is a real number [cite: 811]
    avg_chl = np.mean(fluorescence_signal) 
    
    # 4. Extract harmonic indices (1/T, 2/T, 3/T, 4/T)
    fundamental_freq = 1 / T
    indices = []
    for m in [1, 2, 3, 4]:
        idx = np.argmin(np.abs(freqs - (m * fundamental_freq)))
        indices.append(idx)
        
    # 5. Reconstruction (Right Column of Fig 6) 
    # Summing: Avg + Fund + Harmonics
    reconstructions = []
    current_sum = np.full(N, avg_chl)
    
    for idx in indices:
        # Generate the specific sine wave component: A * cos(2*pi*f*t + phase)
        component = amplitudes[idx] * np.cos(2 * np.pi * freqs[idx] * time + phases[idx])
        current_sum = current_sum + component
        reconstructions.append(current_sum.copy())

    # 6. Plotting
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
    
    # Amplitude Spectrum Plot (Left) [cite: 924, 926]
    colors = ['red', 'orange', 'green', 'skyblue']
    labels = ['1/T (Fund)', '2/T', '3/T', '4/T']
    for i, idx in enumerate(indices):
        ax1.scatter(freqs[idx], amplitudes[idx], color=colors[i], s=100, label=labels[i])
    ax1.set_title("Amplitude Frequency Spectrum")
    ax1.set_xlabel("Frequency (Hz)")
    ax1.set_ylabel("Amplitude")
    ax1.legend()

    # Time-Domain Reconstruction (Right) [cite: 924, 928, 931]
    ax2.plot(time, fluorescence_signal, color='black', linewidth=3, label='Full Signal')
    ax2.plot(time, reconstructions[0], color='red', label='Fund')
    ax2.plot(time, reconstructions[1], color='orange', label='Fund + 2/T')
    # ax2.plot(time, reconstructions[3], color='skyblue', label='Fund + Harmonics')
    
    ax2.set_title("Time-Domain Reconstruction")
    ax2.set_xlabel("Time (s)")
    ax2.set_ylabel("ChlF (rel. units)")
    ax2.legend()
    
    plt.tight_layout()
    plt.show()
    
    
def fig6_plot(
    res: pd.DataFrame,
    flou_str
):
    
    fig, axs = plt.subplots(nrows=3, ncols = 3, figsize=(10, 5))
    
    axs[0,2].plot(res[flou_str], color="black")
    
    axs[0,2].set_ylim(0, 0.4)
    axs[0,2].set_xlim(1000, 2000)
    axs[0,2].set_title("ChlF response reconstruction\nin the time-domain")

# %%
fig6_res, results, fig6_model = fig6_sim(
    m=get_fuente2024(),
    pfd_str=pfd_str,
    pfd_add_str=pfd_add_str
)

print(results)

# fig6_plot(
#     res=fig6_res,
#     flou_str=flou_str
# )

plt.tight_layout()
plt.show()
